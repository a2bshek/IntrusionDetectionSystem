# %%
import matplotlib.pyplot as plt

# %%
Classifiers = ["Decision Tree","Linear Regression","Navie Bayes","Logistic Regression","Random Forest","Gradient Boost","XGBoost","LSTM","DeepBN","GAN"]
TestAccuracy = [0.9999959170633069,0.9969501696427694,0.9321783385918155,0.01413614756549797,0.9999918341266139,0.9999499840255102,1.0,0.9999816417694092,0.7926082514109098,0.9958619170633069]
TrainingTime = [10.846559047698975,5.988180637359619,3.7390005588531494,376.9210436344147,495.71294355392456,6372.175640583038,443.01413614756549797,7966.016467809677,819.1024024486542,130.016467809677]
# TestScore = [100,0.0001,0.6529,0.5652,91.3,100,-47.82,100]

# %%
# Ploting the Accuracy
plt.figure(figsize=(20,5))
plt.title('Test Accuracy')
plt.xlabel('ML Model')
plt.ylabel('Test Accuracy')
plt.bar(Classifiers,TestAccuracy)
plt.show()

# %%
# Ploting the Training Time
plt.figure(figsize=(20,5))
plt.title('Training Time')
plt.xlabel('ML Model')
plt.ylabel('Training Time in seconds')
plt.bar(Classifiers,TrainingTime)
plt.show()
